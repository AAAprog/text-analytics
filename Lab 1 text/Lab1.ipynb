# %%
# Read the content of the text file 
with open('sample.txt', 'r', encoding='utf-8') as file: 
 text_data = file.read() 
print("Raw Text:\n", text_data) 
# Store in another file 
with open('stored_text.txt', 'w', encoding='utf-8') as file: 
 file.write(text_data)
# Out:
# Raw Text:
#  Hello, this is a sample text file.
# This is the second line.

# %%
import pandas as pd 
# Read the CSV file 
df = pd.read_csv('reviews.csv') 
print("Reviews:\n", df['Review'].head()) 
# Save the reviews column to a text file 
df['Review'].to_csv('stored_reviews.txt', index=False, header=False)
# Out:
# Reviews:
#  0    The product is amazing!
# 1     Worst experience ever!
# Name: Review, dtype: object

# %%
# Read the Excel file 
df_excel = pd.read_excel('reviews.xlsx', engine='openpyxl') 
print("First two rows:\n", df_excel.head(2)) 
# Save the first two rows to a text file 
df_excel.head(2).to_csv('extracted_excel.txt', index=False)
# Out:
# First two rows:
#     ID                   Review
# 0   1  The product is amazing!
# 1   2   Worst experience ever!

# %%
import json 
 
# Read the JSON file 
with open('social_data.json', 'r', encoding='utf-8') as file: 
    data = json.load(file) 
print("Extracted City:", data['city']) 
 
# Store the extracted city to a file 
with open('stored_city.txt', 'w', encoding='utf-8') as file: 
    file.write(data['city'])
# Out:
# Extracted City: New York

# %%
import xml.etree.ElementTree as ET 
 
# Parse the XML file 
tree = ET.parse('news.xml') 
root = tree.getroot() 
 
for article in root.findall('article'): 
    title = article.find('title').text 
    print("Extracted Title:", title) 
 
# Store the extracted title to a file 
with open('stored_titles.txt', 'w', encoding='utf-8') as file: 
    for article in root.findall('article'): 
        title = article.find('title').text 
        file.write(title + '\n')
# Out:
# Extracted Title: AI is transforming industries

# %%
pip install PyPDF2
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in links: /usr/share/pip-wheels
# Requirement already satisfied: PyPDF2 in ./.local/lib/python3.12/site-packages (3.0.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import PyPDF2 
# Read the PDF file 
with open('document.pdf', 'rb') as file: 
 reader = PyPDF2.PdfReader(file) 
 text = "\n".join(page.extract_text() for page in reader.pages if page.extract_text()) 
# Print the extracted text 
print("Extracted PDF Text:\n", text) 
# Store the extracted text in a file 
with open('stored_pdf_text.txt', 'w', encoding='utf-8') as output: 
 output.write(text)
# Out:
# Extracted PDF Text:
#  This is a sample PDF document.
# AI is transforming industries and automation.

# %%
import PyPDF2 

# Open the specific file in read-binary mode
with open('Business_Proposal.pdf', 'rb') as file: 
    reader = PyPDF2.PdfReader(file) 
    
    # Extract text from every page and join with newlines
    all_text = "\n".join(page.extract_text() for page in reader.pages if page.extract_text()) 

# Save to the required output file
with open('business_proposal_all.txt', 'w', encoding='utf-8') as output: 
    output.write(all_text)

print("Exercise 1 Complete: business_proposal_all.txt has been created.")
# Out:
# Exercise 1 Complete: business_proposal_all.txt has been created.

# %%
import PyPDF2 

with open('Business_Proposal.pdf', 'rb') as file: 
    reader = PyPDF2.PdfReader(file) 
    
    # Access the second page (index 1)
    # Checking length first prevents errors if the PDF is too short
    if len(reader.pages) >= 2:
        page_2_text = reader.pages[1].extract_text() 
        
        # Save only the text from Page 2
        with open('business_proposal_page_2.txt', 'w', encoding='utf-8') as output: 
            output.write(page_2_text)
        print("Exercise 2 Complete: business_proposal_page_2.txt has been created.")
    else:
        print("Error: The document does not have a second page.")
# Out:
# Exercise 2 Complete: business_proposal_page_2.txt has been created.
